# %%
import keras
import tensorflow as tf
import geopandas
import matplotlib.pyplot as plt
import pandas as pd
import rioxarray
import numpy as np
import IDTreeS_dataset
# Out:
# 2023-09-01 11:33:45.190490: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-09-01 11:33:45.226792: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # Set Parameters for run:

# %%
# Data Parameters
train_test_split_size = 0.2
random_state = 0
shuffle = True

# Architecture Parameters
base_model='ResNet50V2'
activation = 'softmax'

# Compile options
metrics = ['accuracy']
optimizer = keras.optimizers.Adam()
loss_function = keras.losses.CategoricalCrossentropy(from_logits=False)

# Training Parameters
batch_size = 32
epochs = 50

# %% [markdown]
# ### Set Keras backend for image data format

# %%
keras.backend.set_image_data_format('channels_first')

# %% [markdown]
# ### Load ResNet50V2 model from Keras and freeze weights

# %%
if base_model == 'ResNet50V2':
    base_model = tf.keras.applications.ResNet50V2(
        include_top=False,
        weights="imagenet",
        input_tensor=None,
        input_shape=None,
        pooling=None
    )
else:
    raise ValueError('Base model not defined')

# %%
base_model.trainable = False

# %% [markdown]
# ### Load data and set model parameters

# %%
import glob

from rioxarray.exceptions import NoDataInBounds
from sklearn.preprocessing import LabelEncoder

# %%
# Data Loader from IDTreeS Dataset
rgb_paths = glob.glob('./train/RemoteSensing/RGB/*.tif')
bboxes_paths = glob.glob('./train/ITC/train_*.shp')
classes_path = './train/Field/train_data.csv'

# Convert generator dataset in to suitable input for keras
ds = IDTreeS_dataset.IDTreeSDataset(rgb_paths, bboxes_paths, classes_path)

ids, Y, X = ds.get_cutouts()

nclasses = len(np.unique(Y)) #Number of classes in training data

# %%
def preprocess_data(X, Y, nclasses):
    X_p = keras.applications.resnet_v2.preprocess_input(X)
    Y_p = keras.utils.to_categorical(Y, nclasses)
    return X_p, Y_p

X, Y = preprocess_data(X, Y, nclasses)

# %%
# Split train and test data
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=train_test_split_size, random_state=random_state, shuffle=shuffle)

# %% [markdown]
# ### Create new model using the base model plus additional layers

# %%
def create_model():
    # Inputs
    inputs = keras.Input(shape=(3, 100, 100))

    # Run input image through our base model (ResNet)
    x = base_model(inputs, training = False)

    # Convert features from base model to a vector
    x = keras.layers.GlobalAveragePooling2D()(x)

    # # Create additional dense layers to fine tune the model
    # x = keras.layers.Dense(256)(x)
    # x = keras.layers.Dense(64)(x)

    # Create output layer
    outputs = keras.layers.Dense(nclasses, activation=activation)(x)

    return keras.Model(inputs, outputs)

model = create_model()
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 3, 100, 100)]     0
#
#  resnet50v2 (Functional)     (None, 2048, None, None)  23564800
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 9)                 18441
#
# =================================================================
# Total params: 23,583,241
# Trainable params: 18,441
# Non-trainable params: 23,564,800
# _________________________________________________________________

# %%
# Compile the model
model.compile(optimizer=optimizer, 
              loss=loss_function,
              metrics=metrics)

# %%
# Train the model with preprocessed data
history = model.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 13/13 [==============================] - 48s 4s/step - loss: 2.2931 - accuracy: 0.1966 - val_loss: 2.0998 - val_accuracy: 0.3010
# Epoch 2/50
# 13/13 [==============================] - 41s 3s/step - loss: 1.9063 - accuracy: 0.3398 - val_loss: 1.9213 - val_accuracy: 0.3689
# Epoch 3/50
# 13/13 [==============================] - 40s 3s/step - loss: 1.7000 - accuracy: 0.4175 - val_loss: 1.8084 - val_accuracy: 0.3689
# Epoch 4/50
# 13/13 [==============================] - 38s 3s/step - loss: 1.5963 - accuracy: 0.4515 - val_loss: 1.7486 - val_accuracy: 0.3689
# Epoch 5/50
# 13/13 [==============================] - 39s 3s/step - loss: 1.5072 - accuracy: 0.4879 - val_loss: 1.7205 - val_accuracy: 0.3301
# Epoch 6/50
# 13/13 [==============================] - 38s 3s/step - loss: 1.4312 - accuracy: 0.5146 - val_loss: 1.7107 - val_accuracy: 0.3786
# Epoch 7/50
# 13/13 [==============================] - 41s 3s/step - loss: 1.3514 - accuracy: 0.5534 - val_loss: 1.6970 - val_accuracy: 0.3689
# Epoch 8/50
# 13/13 [==============================] - 55s 4s/step - loss: 1.2985 - accuracy: 0.5655 - val_loss: 1.7047 - val_accuracy: 0.3495
# Epoch 9/50
# 13/13 [==============================] - 45s 4s/step - loss: 1.2485 - accuracy: 0.5995 - val_loss: 1.6874 - val_accuracy: 0.4078
# Epoch 10/50
# 13/13 [==============================] - 47s 4s/step - loss: 1.2071 - accuracy: 0.5850 - val_loss: 1.6802 - val_accuracy: 0.3981
# Epoch 11/50
# 13/13 [==============================] - 41s 3s/step - loss: 1.1769 - accuracy: 0.6262 - val_loss: 1.6727 - val_accuracy: 0.3883
# Epoch 12/50
# 13/13 [==============================] - 39s 3s/step - loss: 1.1356 - accuracy: 0.6311 - val_loss: 1.6852 - val_accuracy: 0.3981
# Epoch 13/50
# 13/13 [==============================] - 40s 3s/step - loss: 1.0955 - accuracy: 0.6335 - val_loss: 1.6793 - val_accuracy: 0.3689
# Epoch 14/50
# 13/13 [==============================] - 42s 3s/step - loss: 1.0684 - accuracy: 0.6432 - val_loss: 1.6733 - val_accuracy: 0.3883
# Epoch 15/50
# 13/13 [==============================] - 42s 3s/step - loss: 1.0395 - accuracy: 0.6650 - val_loss: 1.6902 - val_accuracy: 0.3398
# Epoch 16/50
# 13/13 [==============================] - 43s 3s/step - loss: 0.9977 - accuracy: 0.6990 - val_loss: 1.6759 - val_accuracy: 0.3495
# Epoch 17/50
# 13/13 [==============================] - 46s 4s/step - loss: 0.9833 - accuracy: 0.7063 - val_loss: 1.6947 - val_accuracy: 0.3592
# Epoch 18/50
# 13/13 [==============================] - 48s 4s/step - loss: 0.9562 - accuracy: 0.7063 - val_loss: 1.6958 - val_accuracy: 0.3398
# Epoch 19/50
# 13/13 [==============================] - 48s 4s/step - loss: 0.9347 - accuracy: 0.7330 - val_loss: 1.6765 - val_accuracy: 0.3301
# Epoch 20/50
# 13/13 [==============================] - 48s 4s/step - loss: 0.9163 - accuracy: 0.7330 - val_loss: 1.7045 - val_accuracy: 0.3689
# Epoch 21/50
# 13/13 [==============================] - 49s 4s/step - loss: 0.8856 - accuracy: 0.7646 - val_loss: 1.7061 - val_accuracy: 0.3398
# Epoch 22/50
# 13/13 [==============================] - 51s 4s/step - loss: 0.8714 - accuracy: 0.7476 - val_loss: 1.7033 - val_accuracy: 0.3204
# Epoch 23/50
# 13/13 [==============================] - 48s 4s/step - loss: 0.8551 - accuracy: 0.7718 - val_loss: 1.7234 - val_accuracy: 0.3592
# Epoch 24/50
# 13/13 [==============================] - 48s 4s/step - loss: 0.8332 - accuracy: 0.7694 - val_loss: 1.7146 - val_accuracy: 0.3204
# Epoch 25/50
# 13/13 [==============================] - 49s 4s/step - loss: 0.8194 - accuracy: 0.7743 - val_loss: 1.7060 - val_accuracy: 0.3495
# Epoch 26/50
# 13/13 [==============================] - 51s 4s/step - loss: 0.8002 - accuracy: 0.7743 - val_loss: 1.7154 - val_accuracy: 0.3204
# Epoch 27/50
# 13/13 [==============================] - 49s 4s/step - loss: 0.7810 - accuracy: 0.7961 - val_loss: 1.7174 - val_accuracy: 0.3592
# Epoch 28/50
# 13/13 [==============================] - 49s 4s/step - loss: 0.7721 - accuracy: 0.7937 - val_loss: 1.7254 - val_accuracy: 0.3398
# Epoch 29/50
# 13/13 [==============================] - 49s 4s/step - loss: 0.7551 - accuracy: 0.8131 - val_loss: 1.7429 - val_accuracy: 0.3592
# Epoch 30/50
# 13/13 [==============================] - 52s 4s/step - loss: 0.7376 - accuracy: 0.8010 - val_loss: 1.7319 - val_accuracy: 0.3495
# Epoch 31/50
# 13/13 [==============================] - 51s 4s/step - loss: 0.7268 - accuracy: 0.8155 - val_loss: 1.7394 - val_accuracy: 0.3689
# Epoch 32/50
# 13/13 [==============================] - 50s 4s/step - loss: 0.7197 - accuracy: 0.8228 - val_loss: 1.7477 - val_accuracy: 0.3592
# Epoch 33/50
# 13/13 [==============================] - 52s 4s/step - loss: 0.6966 - accuracy: 0.8107 - val_loss: 1.7430 - val_accuracy: 0.3495
# Epoch 34/50
# 13/13 [==============================] - 50s 4s/step - loss: 0.6964 - accuracy: 0.8228 - val_loss: 1.7553 - val_accuracy: 0.3398
# Epoch 35/50
# 13/13 [==============================] - 50s 4s/step - loss: 0.6771 - accuracy: 0.8350 - val_loss: 1.7606 - val_accuracy: 0.3495
# Epoch 36/50
# 13/13 [==============================] - 52s 4s/step - loss: 0.6651 - accuracy: 0.8350 - val_loss: 1.7660 - val_accuracy: 0.3398
# Epoch 37/50
# 13/13 [==============================] - 55s 4s/step - loss: 0.6566 - accuracy: 0.8398 - val_loss: 1.7772 - val_accuracy: 0.3592
# Epoch 38/50
# 13/13 [==============================] - 52s 4s/step - loss: 0.6441 - accuracy: 0.8447 - val_loss: 1.7713 - val_accuracy: 0.3204
# Epoch 39/50
# 13/13 [==============================] - 52s 4s/step - loss: 0.6340 - accuracy: 0.8447 - val_loss: 1.7748 - val_accuracy: 0.3495
# Epoch 40/50
# 13/13 [==============================] - 55s 4s/step - loss: 0.6244 - accuracy: 0.8568 - val_loss: 1.7801 - val_accuracy: 0.3689
# Epoch 41/50
# 13/13 [==============================] - 52s 4s/step - loss: 0.6122 - accuracy: 0.8544 - val_loss: 1.7957 - val_accuracy: 0.3495
# Epoch 42/50
# 13/13 [==============================] - 53s 4s/step - loss: 0.6104 - accuracy: 0.8471 - val_loss: 1.8074 - val_accuracy: 0.3301
# Epoch 43/50
# 13/13 [==============================] - 52s 4s/step - loss: 0.5989 - accuracy: 0.8689 - val_loss: 1.8000 - val_accuracy: 0.3495
# Epoch 44/50
# 13/13 [==============================] - 54s 4s/step - loss: 0.5878 - accuracy: 0.8762 - val_loss: 1.7837 - val_accuracy: 0.3981
# Epoch 45/50
# 13/13 [==============================] - 52s 4s/step - loss: 0.5791 - accuracy: 0.8495 - val_loss: 1.8207 - val_accuracy: 0.3398
# Epoch 46/50
# 13/13 [==============================] - 52s 4s/step - loss: 0.5688 - accuracy: 0.8786 - val_loss: 1.8029 - val_accuracy: 0.3689
# Epoch 47/50
# 13/13 [==============================] - 54s 4s/step - loss: 0.5591 - accuracy: 0.8738 - val_loss: 1.8268 - val_accuracy: 0.3592
# Epoch 48/50
# 13/13 [==============================] - 52s 4s/step - loss: 0.5535 - accuracy: 0.8859 - val_loss: 1.8191 - val_accuracy: 0.3495
# Epoch 49/50
# 13/13 [==============================] - 53s 4s/step - loss: 0.5427 - accuracy: 0.8811 - val_loss: 1.8446 - val_accuracy: 0.3689
# Epoch 50/50
# 13/13 [==============================] - 52s 4s/step - loss: 0.5382 - accuracy: 0.8859 - val_loss: 1.8352 - val_accuracy: 0.3495

# %%
# Predict on the train and test set
ypred_train = np.argmax(model.predict(X_train), axis=1)
ypred_val = np.argmax(model.predict(X_test), axis=1)
# Out:
# 13/13 [==============================] - 29s 2s/step
# 4/4 [==============================] - 7s 2s/step

# %%
import seaborn as sns
def plot_history(history, metrics):
    """
    Plot the training history

    Args:
        history (keras History object that is returned by model.fit())
        metrics (str, list): Metric or a list of metrics to plot
    """
    history_df = pd.DataFrame.from_dict(history.history)
    sns.lineplot(data=history_df[metrics])
    plt.xlabel("epochs")
    plt.ylabel("metric")

# %%
plot_history(history, ['loss', 'accuracy', 'val_loss', 'val_accuracy'] )

# %%
from sklearn.metrics import confusion_matrix

# Training data confusion matrix
true_train_label = np.argmax(y_train, axis=1)
matrix = confusion_matrix(true_train_label, ypred_train)
sns.heatmap(matrix, annot=True)
# Out:
# <Axes: >

# %%
from sklearn.metrics import confusion_matrix

# Validation data confusion matrix
true_val_label = np.argmax(y_test, axis=1)
matrix = confusion_matrix(true_val_label, ypred_val)
sns.heatmap(matrix, annot=True)
# Out:
# <Axes: >

# %%
import random 
print ('Correct predictions, Total samples, Accuracy')
print (np.count_nonzero(ypred_train - np.argmax(y_train, axis=1) == 0), y_train.shape[0], np.count_nonzero(ypred_train - np.argmax(y_train, axis=1) == 0)/y_train.shape[0])
print (np.count_nonzero(ypred_val - np.argmax(y_test, axis=1) == 0), y_test.shape[0], np.count_nonzero(ypred_val - np.argmax(y_test, axis=1) == 0)/y_test.shape[0])
# Out:
# Correct predictions, Total samples, Accuracy
# 366 412 0.8883495145631068
# 36 103 0.34951456310679613
