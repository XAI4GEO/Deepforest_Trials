# %%
import keras
import tensorflow as tf
# Out:
# 2023-08-30 12:17:17.721852: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-08-30 12:17:17.821631: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ### Set Keras backend for image data format

# %%
keras.backend.set_image_data_format('channels_first')

# %% [markdown]
# ### Load ResNet50V2 model from Keras and freeze weights

# %%
base_model = tf.keras.applications.ResNet50V2(
    include_top=False,
    weights="imagenet",
    input_tensor=None,
    input_shape=None,
    pooling=None
)

# %%
base_model.summary()
# Out:
# Model: "resnet50v2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 3, None, No  0           []
#                                 ne)]
#
#  conv1_pad (ZeroPadding2D)      (None, 3, None, Non  0           ['input_1[0][0]']
#                                 e)
#
#  conv1_conv (Conv2D)            (None, 64, None, No  9472        ['conv1_pad[0][0]']
#                                 ne)
#
#  pool1_pad (ZeroPadding2D)      (None, 64, None, No  0           ['conv1_conv[0][0]']
#                                 ne)
#
#  pool1_pool (MaxPooling2D)      (None, 64, None, No  0           ['pool1_pad[0][0]']
#                                 ne)
#
#  conv2_block1_preact_bn (BatchN  (None, 64, None, No  256        ['pool1_pool[0][0]']
#  ormalization)                  ne)
#
#  conv2_block1_preact_relu (Acti  (None, 64, None, No  0          ['conv2_block1_preact_bn[0][0]']
#  vation)                        ne)
#
#  conv2_block1_1_conv (Conv2D)   (None, 64, None, No  4096        ['conv2_block1_preact_relu[0][0]'
#                                 ne)                              ]
#
#  conv2_block1_1_bn (BatchNormal  (None, 64, None, No  256        ['conv2_block1_1_conv[0][0]']
#  ization)                       ne)
#
#  conv2_block1_1_relu (Activatio  (None, 64, None, No  0          ['conv2_block1_1_bn[0][0]']
#  n)                             ne)
#
#  conv2_block1_2_pad (ZeroPaddin  (None, 64, None, No  0          ['conv2_block1_1_relu[0][0]']
#  g2D)                           ne)
#
#  conv2_block1_2_conv (Conv2D)   (None, 64, None, No  36864       ['conv2_block1_2_pad[0][0]']
#                                 ne)
#
#  conv2_block1_2_bn (BatchNormal  (None, 64, None, No  256        ['conv2_block1_2_conv[0][0]']
#  ization)                       ne)
#
#  conv2_block1_2_relu (Activatio  (None, 64, None, No  0          ['conv2_block1_2_bn[0][0]']
#  n)                             ne)
#
#  conv2_block1_0_conv (Conv2D)   (None, 256, None, N  16640       ['conv2_block1_preact_relu[0][0]'
#                                 one)                             ]
#
#  conv2_block1_3_conv (Conv2D)   (None, 256, None, N  16640       ['conv2_block1_2_relu[0][0]']
#                                 one)
#
#  conv2_block1_out (Add)         (None, 256, None, N  0           ['conv2_block1_0_conv[0][0]',
#                                 one)                              'conv2_block1_3_conv[0][0]']
#
#  conv2_block2_preact_bn (BatchN  (None, 256, None, N  1024       ['conv2_block1_out[0][0]']
#  ormalization)                  one)
#
#  conv2_block2_preact_relu (Acti  (None, 256, None, N  0          ['conv2_block2_preact_bn[0][0]']
#  vation)                        one)
#
#  conv2_block2_1_conv (Conv2D)   (None, 64, None, No  16384       ['conv2_block2_preact_relu[0][0]'
#                                 ne)                              ]
#
#  conv2_block2_1_bn (BatchNormal  (None, 64, None, No  256        ['conv2_block2_1_conv[0][0]']
#  ization)                       ne)
#
#  conv2_block2_1_relu (Activatio  (None, 64, None, No  0          ['conv2_block2_1_bn[0][0]']
#  n)                             ne)
#
#  conv2_block2_2_pad (ZeroPaddin  (None, 64, None, No  0          ['conv2_block2_1_relu[0][0]']
#  g2D)                           ne)
#
#  conv2_block2_2_conv (Conv2D)   (None, 64, None, No  36864       ['conv2_block2_2_pad[0][0]']
#                                 ne)
#
#  conv2_block2_2_bn (BatchNormal  (None, 64, None, No  256        ['conv2_block2_2_conv[0][0]']
#  ization)                       ne)
#
#  conv2_block2_2_relu (Activatio  (None, 64, None, No  0          ['conv2_block2_2_bn[0][0]']
#  n)                             ne)
#
#  conv2_block2_3_conv (Conv2D)   (None, 256, None, N  16640       ['conv2_block2_2_relu[0][0]']
#                                 one)
#
#  conv2_block2_out (Add)         (None, 256, None, N  0           ['conv2_block1_out[0][0]',
#                                 one)                              'conv2_block2_3_conv[0][0]']
#
#  conv2_block3_preact_bn (BatchN  (None, 256, None, N  1024       ['conv2_block2_out[0][0]']
#  ormalization)                  one)
#
#  conv2_block3_preact_relu (Acti  (None, 256, None, N  0          ['conv2_block3_preact_bn[0][0]']
#  vation)                        one)
#
#  conv2_block3_1_conv (Conv2D)   (None, 64, None, No  16384       ['conv2_block3_preact_relu[0][0]'
#                                 ne)                              ]
#
#  conv2_block3_1_bn (BatchNormal  (None, 64, None, No  256        ['conv2_block3_1_conv[0][0]']
#  ization)                       ne)
#
#  conv2_block3_1_relu (Activatio  (None, 64, None, No  0          ['conv2_block3_1_bn[0][0]']
#  n)                             ne)
#
#  conv2_block3_2_pad (ZeroPaddin  (None, 64, None, No  0          ['conv2_block3_1_relu[0][0]']
#  g2D)                           ne)
#
#  conv2_block3_2_conv (Conv2D)   (None, 64, None, No  36864       ['conv2_block3_2_pad[0][0]']
#                                 ne)
#
#  conv2_block3_2_bn (BatchNormal  (None, 64, None, No  256        ['conv2_block3_2_conv[0][0]']
#  ization)                       ne)
#
#  conv2_block3_2_relu (Activatio  (None, 64, None, No  0          ['conv2_block3_2_bn[0][0]']
#  n)                             ne)
#
#  max_pooling2d (MaxPooling2D)   (None, 256, None, N  0           ['conv2_block2_out[0][0]']
#                                 one)
#
#  conv2_block3_3_conv (Conv2D)   (None, 256, None, N  16640       ['conv2_block3_2_relu[0][0]']
#                                 one)
#
#  conv2_block3_out (Add)         (None, 256, None, N  0           ['max_pooling2d[0][0]',
#                                 one)                              'conv2_block3_3_conv[0][0]']
#
#  conv3_block1_preact_bn (BatchN  (None, 256, None, N  1024       ['conv2_block3_out[0][0]']
#  ormalization)                  one)
#
#  conv3_block1_preact_relu (Acti  (None, 256, None, N  0          ['conv3_block1_preact_bn[0][0]']
#  vation)                        one)
#
#  conv3_block1_1_conv (Conv2D)   (None, 128, None, N  32768       ['conv3_block1_preact_relu[0][0]'
#                                 one)                             ]
#
#  conv3_block1_1_bn (BatchNormal  (None, 128, None, N  512        ['conv3_block1_1_conv[0][0]']
#  ization)                       one)
#
#  conv3_block1_1_relu (Activatio  (None, 128, None, N  0          ['conv3_block1_1_bn[0][0]']
#  n)                             one)
#
#  conv3_block1_2_pad (ZeroPaddin  (None, 128, None, N  0          ['conv3_block1_1_relu[0][0]']
#  g2D)                           one)
#
#  conv3_block1_2_conv (Conv2D)   (None, 128, None, N  147456      ['conv3_block1_2_pad[0][0]']
#                                 one)
#
#  conv3_block1_2_bn (BatchNormal  (None, 128, None, N  512        ['conv3_block1_2_conv[0][0]']
#  ization)                       one)
#
#  conv3_block1_2_relu (Activatio  (None, 128, None, N  0          ['conv3_block1_2_bn[0][0]']
#  n)                             one)
#
#  conv3_block1_0_conv (Conv2D)   (None, 512, None, N  131584      ['conv3_block1_preact_relu[0][0]'
#                                 one)                             ]
#
#  conv3_block1_3_conv (Conv2D)   (None, 512, None, N  66048       ['conv3_block1_2_relu[0][0]']
#                                 one)
#
#  conv3_block1_out (Add)         (None, 512, None, N  0           ['conv3_block1_0_conv[0][0]',
#                                 one)                              'conv3_block1_3_conv[0][0]']
#
#  conv3_block2_preact_bn (BatchN  (None, 512, None, N  2048       ['conv3_block1_out[0][0]']
#  ormalization)                  one)
#
#  conv3_block2_preact_relu (Acti  (None, 512, None, N  0          ['conv3_block2_preact_bn[0][0]']
#  vation)                        one)
#
#  conv3_block2_1_conv (Conv2D)   (None, 128, None, N  65536       ['conv3_block2_preact_relu[0][0]'
#                                 one)                             ]
#
#  conv3_block2_1_bn (BatchNormal  (None, 128, None, N  512        ['conv3_block2_1_conv[0][0]']
#  ization)                       one)
#
#  conv3_block2_1_relu (Activatio  (None, 128, None, N  0          ['conv3_block2_1_bn[0][0]']
#  n)                             one)
#
#  conv3_block2_2_pad (ZeroPaddin  (None, 128, None, N  0          ['conv3_block2_1_relu[0][0]']
#  g2D)                           one)
#
#  conv3_block2_2_conv (Conv2D)   (None, 128, None, N  147456      ['conv3_block2_2_pad[0][0]']
#                                 one)
#
#  conv3_block2_2_bn (BatchNormal  (None, 128, None, N  512        ['conv3_block2_2_conv[0][0]']
#  ization)                       one)
#
#  conv3_block2_2_relu (Activatio  (None, 128, None, N  0          ['conv3_block2_2_bn[0][0]']
#  n)                             one)
#
#  conv3_block2_3_conv (Conv2D)   (None, 512, None, N  66048       ['conv3_block2_2_relu[0][0]']
#                                 one)
#
#  conv3_block2_out (Add)         (None, 512, None, N  0           ['conv3_block1_out[0][0]',
#                                 one)                              'conv3_block2_3_conv[0][0]']
#
#  conv3_block3_preact_bn (BatchN  (None, 512, None, N  2048       ['conv3_block2_out[0][0]']
#  ormalization)                  one)
#
#  conv3_block3_preact_relu (Acti  (None, 512, None, N  0          ['conv3_block3_preact_bn[0][0]']
#  vation)                        one)
#
#  conv3_block3_1_conv (Conv2D)   (None, 128, None, N  65536       ['conv3_block3_preact_relu[0][0]'
#                                 one)                             ]
#
#  conv3_block3_1_bn (BatchNormal  (None, 128, None, N  512        ['conv3_block3_1_conv[0][0]']
#  ization)                       one)
#
#  conv3_block3_1_relu (Activatio  (None, 128, None, N  0          ['conv3_block3_1_bn[0][0]']
#  n)                             one)
#
#  conv3_block3_2_pad (ZeroPaddin  (None, 128, None, N  0          ['conv3_block3_1_relu[0][0]']
#  g2D)                           one)
#
#  conv3_block3_2_conv (Conv2D)   (None, 128, None, N  147456      ['conv3_block3_2_pad[0][0]']
#                                 one)
#
#  conv3_block3_2_bn (BatchNormal  (None, 128, None, N  512        ['conv3_block3_2_conv[0][0]']
#  ization)                       one)
#
#  conv3_block3_2_relu (Activatio  (None, 128, None, N  0          ['conv3_block3_2_bn[0][0]']
#  n)                             one)
#
#  conv3_block3_3_conv (Conv2D)   (None, 512, None, N  66048       ['conv3_block3_2_relu[0][0]']
#                                 one)
#
#  conv3_block3_out (Add)         (None, 512, None, N  0           ['conv3_block2_out[0][0]',
#                                 one)                              'conv3_block3_3_conv[0][0]']
#
#  conv3_block4_preact_bn (BatchN  (None, 512, None, N  2048       ['conv3_block3_out[0][0]']
#  ormalization)                  one)
#
#  conv3_block4_preact_relu (Acti  (None, 512, None, N  0          ['conv3_block4_preact_bn[0][0]']
#  vation)                        one)
#
#  conv3_block4_1_conv (Conv2D)   (None, 128, None, N  65536       ['conv3_block4_preact_relu[0][0]'
#                                 one)                             ]
#
#  conv3_block4_1_bn (BatchNormal  (None, 128, None, N  512        ['conv3_block4_1_conv[0][0]']
#  ization)                       one)
#
#  conv3_block4_1_relu (Activatio  (None, 128, None, N  0          ['conv3_block4_1_bn[0][0]']
#  n)                             one)
#
#  conv3_block4_2_pad (ZeroPaddin  (None, 128, None, N  0          ['conv3_block4_1_relu[0][0]']
#  g2D)                           one)
#
#  conv3_block4_2_conv (Conv2D)   (None, 128, None, N  147456      ['conv3_block4_2_pad[0][0]']
#                                 one)
#
#  conv3_block4_2_bn (BatchNormal  (None, 128, None, N  512        ['conv3_block4_2_conv[0][0]']
#  ization)                       one)
#
#  conv3_block4_2_relu (Activatio  (None, 128, None, N  0          ['conv3_block4_2_bn[0][0]']
#  n)                             one)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 512, None, N  0          ['conv3_block3_out[0][0]']
#                                 one)
#
#  conv3_block4_3_conv (Conv2D)   (None, 512, None, N  66048       ['conv3_block4_2_relu[0][0]']
#                                 one)
#
#  conv3_block4_out (Add)         (None, 512, None, N  0           ['max_pooling2d_1[0][0]',
#                                 one)                              'conv3_block4_3_conv[0][0]']
#
#  conv4_block1_preact_bn (BatchN  (None, 512, None, N  2048       ['conv3_block4_out[0][0]']
#  ormalization)                  one)
#
#  conv4_block1_preact_relu (Acti  (None, 512, None, N  0          ['conv4_block1_preact_bn[0][0]']
#  vation)                        one)
#
#  conv4_block1_1_conv (Conv2D)   (None, 256, None, N  131072      ['conv4_block1_preact_relu[0][0]'
#                                 one)                             ]
#
#  conv4_block1_1_bn (BatchNormal  (None, 256, None, N  1024       ['conv4_block1_1_conv[0][0]']
#  ization)                       one)
#
#  conv4_block1_1_relu (Activatio  (None, 256, None, N  0          ['conv4_block1_1_bn[0][0]']
#  n)                             one)
#
#  conv4_block1_2_pad (ZeroPaddin  (None, 256, None, N  0          ['conv4_block1_1_relu[0][0]']
#  g2D)                           one)
#
#  conv4_block1_2_conv (Conv2D)   (None, 256, None, N  589824      ['conv4_block1_2_pad[0][0]']
#                                 one)
#
#  conv4_block1_2_bn (BatchNormal  (None, 256, None, N  1024       ['conv4_block1_2_conv[0][0]']
#  ization)                       one)
#
#  conv4_block1_2_relu (Activatio  (None, 256, None, N  0          ['conv4_block1_2_bn[0][0]']
#  n)                             one)
#
#  conv4_block1_0_conv (Conv2D)   (None, 1024, None,   525312      ['conv4_block1_preact_relu[0][0]'
#                                 None)                            ]
#
#  conv4_block1_3_conv (Conv2D)   (None, 1024, None,   263168      ['conv4_block1_2_relu[0][0]']
#                                 None)
#
#  conv4_block1_out (Add)         (None, 1024, None,   0           ['conv4_block1_0_conv[0][0]',
#                                 None)                             'conv4_block1_3_conv[0][0]']
#
#  conv4_block2_preact_bn (BatchN  (None, 1024, None,   4096       ['conv4_block1_out[0][0]']
#  ormalization)                  None)
#
#  conv4_block2_preact_relu (Acti  (None, 1024, None,   0          ['conv4_block2_preact_bn[0][0]']
#  vation)                        None)
#
#  conv4_block2_1_conv (Conv2D)   (None, 256, None, N  262144      ['conv4_block2_preact_relu[0][0]'
#                                 one)                             ]
#
#  conv4_block2_1_bn (BatchNormal  (None, 256, None, N  1024       ['conv4_block2_1_conv[0][0]']
#  ization)                       one)
#
#  conv4_block2_1_relu (Activatio  (None, 256, None, N  0          ['conv4_block2_1_bn[0][0]']
#  n)                             one)
#
#  conv4_block2_2_pad (ZeroPaddin  (None, 256, None, N  0          ['conv4_block2_1_relu[0][0]']
#  g2D)                           one)
#
#  conv4_block2_2_conv (Conv2D)   (None, 256, None, N  589824      ['conv4_block2_2_pad[0][0]']
#                                 one)
#
#  conv4_block2_2_bn (BatchNormal  (None, 256, None, N  1024       ['conv4_block2_2_conv[0][0]']
#  ization)                       one)
#
#  conv4_block2_2_relu (Activatio  (None, 256, None, N  0          ['conv4_block2_2_bn[0][0]']
#  n)                             one)
#
#  conv4_block2_3_conv (Conv2D)   (None, 1024, None,   263168      ['conv4_block2_2_relu[0][0]']
#                                 None)
#
#  conv4_block2_out (Add)         (None, 1024, None,   0           ['conv4_block1_out[0][0]',
#                                 None)                             'conv4_block2_3_conv[0][0]']
#
#  conv4_block3_preact_bn (BatchN  (None, 1024, None,   4096       ['conv4_block2_out[0][0]']
#  ormalization)                  None)
#
#  conv4_block3_preact_relu (Acti  (None, 1024, None,   0          ['conv4_block3_preact_bn[0][0]']
#  vation)                        None)
#
#  conv4_block3_1_conv (Conv2D)   (None, 256, None, N  262144      ['conv4_block3_preact_relu[0][0]'
#                                 one)                             ]
#
#  conv4_block3_1_bn (BatchNormal  (None, 256, None, N  1024       ['conv4_block3_1_conv[0][0]']
#  ization)                       one)
#
#  conv4_block3_1_relu (Activatio  (None, 256, None, N  0          ['conv4_block3_1_bn[0][0]']
#  n)                             one)
#
#  conv4_block3_2_pad (ZeroPaddin  (None, 256, None, N  0          ['conv4_block3_1_relu[0][0]']
#  g2D)                           one)
#
#  conv4_block3_2_conv (Conv2D)   (None, 256, None, N  589824      ['conv4_block3_2_pad[0][0]']
#                                 one)
#
#  conv4_block3_2_bn (BatchNormal  (None, 256, None, N  1024       ['conv4_block3_2_conv[0][0]']
#  ization)                       one)
#
#  conv4_block3_2_relu (Activatio  (None, 256, None, N  0          ['conv4_block3_2_bn[0][0]']
#  n)                             one)
#
#  conv4_block3_3_conv (Conv2D)   (None, 1024, None,   263168      ['conv4_block3_2_relu[0][0]']
#                                 None)
#
#  conv4_block3_out (Add)         (None, 1024, None,   0           ['conv4_block2_out[0][0]',
#                                 None)                             'conv4_block3_3_conv[0][0]']
#
#  conv4_block4_preact_bn (BatchN  (None, 1024, None,   4096       ['conv4_block3_out[0][0]']
#  ormalization)                  None)
#
#  conv4_block4_preact_relu (Acti  (None, 1024, None,   0          ['conv4_block4_preact_bn[0][0]']
#  vation)                        None)
#
#  conv4_block4_1_conv (Conv2D)   (None, 256, None, N  262144      ['conv4_block4_preact_relu[0][0]'
#                                 one)                             ]
#
#  conv4_block4_1_bn (BatchNormal  (None, 256, None, N  1024       ['conv4_block4_1_conv[0][0]']
#  ization)                       one)
#
#  conv4_block4_1_relu (Activatio  (None, 256, None, N  0          ['conv4_block4_1_bn[0][0]']
#  n)                             one)
#
#  conv4_block4_2_pad (ZeroPaddin  (None, 256, None, N  0          ['conv4_block4_1_relu[0][0]']
#  g2D)                           one)
#
#  conv4_block4_2_conv (Conv2D)   (None, 256, None, N  589824      ['conv4_block4_2_pad[0][0]']
#                                 one)
#
#  conv4_block4_2_bn (BatchNormal  (None, 256, None, N  1024       ['conv4_block4_2_conv[0][0]']
#  ization)                       one)
#
#  conv4_block4_2_relu (Activatio  (None, 256, None, N  0          ['conv4_block4_2_bn[0][0]']
#  n)                             one)
#
#  conv4_block4_3_conv (Conv2D)   (None, 1024, None,   263168      ['conv4_block4_2_relu[0][0]']
#                                 None)
#
#  conv4_block4_out (Add)         (None, 1024, None,   0           ['conv4_block3_out[0][0]',
#                                 None)                             'conv4_block4_3_conv[0][0]']
#
#  conv4_block5_preact_bn (BatchN  (None, 1024, None,   4096       ['conv4_block4_out[0][0]']
#  ormalization)                  None)
#
#  conv4_block5_preact_relu (Acti  (None, 1024, None,   0          ['conv4_block5_preact_bn[0][0]']
#  vation)                        None)
#
#  conv4_block5_1_conv (Conv2D)   (None, 256, None, N  262144      ['conv4_block5_preact_relu[0][0]'
#                                 one)                             ]
#
#  conv4_block5_1_bn (BatchNormal  (None, 256, None, N  1024       ['conv4_block5_1_conv[0][0]']
#  ization)                       one)
#
#  conv4_block5_1_relu (Activatio  (None, 256, None, N  0          ['conv4_block5_1_bn[0][0]']
#  n)                             one)
#
#  conv4_block5_2_pad (ZeroPaddin  (None, 256, None, N  0          ['conv4_block5_1_relu[0][0]']
#  g2D)                           one)
#
#  conv4_block5_2_conv (Conv2D)   (None, 256, None, N  589824      ['conv4_block5_2_pad[0][0]']
#                                 one)
#
#  conv4_block5_2_bn (BatchNormal  (None, 256, None, N  1024       ['conv4_block5_2_conv[0][0]']
#  ization)                       one)
#
#  conv4_block5_2_relu (Activatio  (None, 256, None, N  0          ['conv4_block5_2_bn[0][0]']
#  n)                             one)
#
#  conv4_block5_3_conv (Conv2D)   (None, 1024, None,   263168      ['conv4_block5_2_relu[0][0]']
#                                 None)
#
#  conv4_block5_out (Add)         (None, 1024, None,   0           ['conv4_block4_out[0][0]',
#                                 None)                             'conv4_block5_3_conv[0][0]']
#
#  conv4_block6_preact_bn (BatchN  (None, 1024, None,   4096       ['conv4_block5_out[0][0]']
#  ormalization)                  None)
#
#  conv4_block6_preact_relu (Acti  (None, 1024, None,   0          ['conv4_block6_preact_bn[0][0]']
#  vation)                        None)
#
#  conv4_block6_1_conv (Conv2D)   (None, 256, None, N  262144      ['conv4_block6_preact_relu[0][0]'
#                                 one)                             ]
#
#  conv4_block6_1_bn (BatchNormal  (None, 256, None, N  1024       ['conv4_block6_1_conv[0][0]']
#  ization)                       one)
#
#  conv4_block6_1_relu (Activatio  (None, 256, None, N  0          ['conv4_block6_1_bn[0][0]']
#  n)                             one)
#
#  conv4_block6_2_pad (ZeroPaddin  (None, 256, None, N  0          ['conv4_block6_1_relu[0][0]']
#  g2D)                           one)
#
#  conv4_block6_2_conv (Conv2D)   (None, 256, None, N  589824      ['conv4_block6_2_pad[0][0]']
#                                 one)
#
#  conv4_block6_2_bn (BatchNormal  (None, 256, None, N  1024       ['conv4_block6_2_conv[0][0]']
#  ization)                       one)
#
#  conv4_block6_2_relu (Activatio  (None, 256, None, N  0          ['conv4_block6_2_bn[0][0]']
#  n)                             one)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 1024, None,   0          ['conv4_block5_out[0][0]']
#                                 None)
#
#  conv4_block6_3_conv (Conv2D)   (None, 1024, None,   263168      ['conv4_block6_2_relu[0][0]']
#                                 None)
#
#  conv4_block6_out (Add)         (None, 1024, None,   0           ['max_pooling2d_2[0][0]',
#                                 None)                             'conv4_block6_3_conv[0][0]']
#
#  conv5_block1_preact_bn (BatchN  (None, 1024, None,   4096       ['conv4_block6_out[0][0]']
#  ormalization)                  None)
#
#  conv5_block1_preact_relu (Acti  (None, 1024, None,   0          ['conv5_block1_preact_bn[0][0]']
#  vation)                        None)
#
#  conv5_block1_1_conv (Conv2D)   (None, 512, None, N  524288      ['conv5_block1_preact_relu[0][0]'
#                                 one)                             ]
#
#  conv5_block1_1_bn (BatchNormal  (None, 512, None, N  2048       ['conv5_block1_1_conv[0][0]']
#  ization)                       one)
#
#  conv5_block1_1_relu (Activatio  (None, 512, None, N  0          ['conv5_block1_1_bn[0][0]']
#  n)                             one)
#
#  conv5_block1_2_pad (ZeroPaddin  (None, 512, None, N  0          ['conv5_block1_1_relu[0][0]']
#  g2D)                           one)
#
#  conv5_block1_2_conv (Conv2D)   (None, 512, None, N  2359296     ['conv5_block1_2_pad[0][0]']
#                                 one)
#
#  conv5_block1_2_bn (BatchNormal  (None, 512, None, N  2048       ['conv5_block1_2_conv[0][0]']
#  ization)                       one)
#
#  conv5_block1_2_relu (Activatio  (None, 512, None, N  0          ['conv5_block1_2_bn[0][0]']
#  n)                             one)
#
#  conv5_block1_0_conv (Conv2D)   (None, 2048, None,   2099200     ['conv5_block1_preact_relu[0][0]'
#                                 None)                            ]
#
#  conv5_block1_3_conv (Conv2D)   (None, 2048, None,   1050624     ['conv5_block1_2_relu[0][0]']
#                                 None)
#
#  conv5_block1_out (Add)         (None, 2048, None,   0           ['conv5_block1_0_conv[0][0]',
#                                 None)                             'conv5_block1_3_conv[0][0]']
#
#  conv5_block2_preact_bn (BatchN  (None, 2048, None,   8192       ['conv5_block1_out[0][0]']
#  ormalization)                  None)
#
#  conv5_block2_preact_relu (Acti  (None, 2048, None,   0          ['conv5_block2_preact_bn[0][0]']
#  vation)                        None)
#
#  conv5_block2_1_conv (Conv2D)   (None, 512, None, N  1048576     ['conv5_block2_preact_relu[0][0]'
#                                 one)                             ]
#
#  conv5_block2_1_bn (BatchNormal  (None, 512, None, N  2048       ['conv5_block2_1_conv[0][0]']
#  ization)                       one)
#
#  conv5_block2_1_relu (Activatio  (None, 512, None, N  0          ['conv5_block2_1_bn[0][0]']
#  n)                             one)
#
#  conv5_block2_2_pad (ZeroPaddin  (None, 512, None, N  0          ['conv5_block2_1_relu[0][0]']
#  g2D)                           one)
#
#  conv5_block2_2_conv (Conv2D)   (None, 512, None, N  2359296     ['conv5_block2_2_pad[0][0]']
#                                 one)
#
#  conv5_block2_2_bn (BatchNormal  (None, 512, None, N  2048       ['conv5_block2_2_conv[0][0]']
#  ization)                       one)
#
#  conv5_block2_2_relu (Activatio  (None, 512, None, N  0          ['conv5_block2_2_bn[0][0]']
#  n)                             one)
#
#  conv5_block2_3_conv (Conv2D)   (None, 2048, None,   1050624     ['conv5_block2_2_relu[0][0]']
#                                 None)
#
#  conv5_block2_out (Add)         (None, 2048, None,   0           ['conv5_block1_out[0][0]',
#                                 None)                             'conv5_block2_3_conv[0][0]']
#
#  conv5_block3_preact_bn (BatchN  (None, 2048, None,   8192       ['conv5_block2_out[0][0]']
#  ormalization)                  None)
#
#  conv5_block3_preact_relu (Acti  (None, 2048, None,   0          ['conv5_block3_preact_bn[0][0]']
#  vation)                        None)
#
#  conv5_block3_1_conv (Conv2D)   (None, 512, None, N  1048576     ['conv5_block3_preact_relu[0][0]'
#                                 one)                             ]
#
#  conv5_block3_1_bn (BatchNormal  (None, 512, None, N  2048       ['conv5_block3_1_conv[0][0]']
#  ization)                       one)
#
#  conv5_block3_1_relu (Activatio  (None, 512, None, N  0          ['conv5_block3_1_bn[0][0]']
#  n)                             one)
#
#  conv5_block3_2_pad (ZeroPaddin  (None, 512, None, N  0          ['conv5_block3_1_relu[0][0]']
#  g2D)                           one)
#
#  conv5_block3_2_conv (Conv2D)   (None, 512, None, N  2359296     ['conv5_block3_2_pad[0][0]']
#                                 one)
#
#  conv5_block3_2_bn (BatchNormal  (None, 512, None, N  2048       ['conv5_block3_2_conv[0][0]']
#  ization)                       one)
#
#  conv5_block3_2_relu (Activatio  (None, 512, None, N  0          ['conv5_block3_2_bn[0][0]']
#  n)                             one)
#
#  conv5_block3_3_conv (Conv2D)   (None, 2048, None,   1050624     ['conv5_block3_2_relu[0][0]']
#                                 None)
#
#  conv5_block3_out (Add)         (None, 2048, None,   0           ['conv5_block2_out[0][0]',
#                                 None)                             'conv5_block3_3_conv[0][0]']
#
#  post_bn (BatchNormalization)   (None, 2048, None,   8192        ['conv5_block3_out[0][0]']
#                                 None)
#
#  post_relu (Activation)         (None, 2048, None,   0           ['post_bn[0][0]']
#                                 None)
#
# ==================================================================================================
# Total params: 23,564,800
# Trainable params: 23,519,360
# Non-trainable params: 45,440
# __________________________________________________________________________________________________

# %%
base_model.trainable = False

# %%
base_model.summary()
# Out:
# Model: "resnet50v2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 3, None, No  0           []
#                                 ne)]
#
#  conv1_pad (ZeroPadding2D)      (None, 3, None, Non  0           ['input_1[0][0]']
#                                 e)
#
#  conv1_conv (Conv2D)            (None, 64, None, No  9472        ['conv1_pad[0][0]']
#                                 ne)
#
#  pool1_pad (ZeroPadding2D)      (None, 64, None, No  0           ['conv1_conv[0][0]']
#                                 ne)
#
#  pool1_pool (MaxPooling2D)      (None, 64, None, No  0           ['pool1_pad[0][0]']
#                                 ne)
#
#  conv2_block1_preact_bn (BatchN  (None, 64, None, No  256        ['pool1_pool[0][0]']
#  ormalization)                  ne)
#
#  conv2_block1_preact_relu (Acti  (None, 64, None, No  0          ['conv2_block1_preact_bn[0][0]']
#  vation)                        ne)
#
#  conv2_block1_1_conv (Conv2D)   (None, 64, None, No  4096        ['conv2_block1_preact_relu[0][0]'
#                                 ne)                              ]
#
#  conv2_block1_1_bn (BatchNormal  (None, 64, None, No  256        ['conv2_block1_1_conv[0][0]']
#  ization)                       ne)
#
#  conv2_block1_1_relu (Activatio  (None, 64, None, No  0          ['conv2_block1_1_bn[0][0]']
#  n)                             ne)
#
#  conv2_block1_2_pad (ZeroPaddin  (None, 64, None, No  0          ['conv2_block1_1_relu[0][0]']
#  g2D)                           ne)
#
#  conv2_block1_2_conv (Conv2D)   (None, 64, None, No  36864       ['conv2_block1_2_pad[0][0]']
#                                 ne)
#
#  conv2_block1_2_bn (BatchNormal  (None, 64, None, No  256        ['conv2_block1_2_conv[0][0]']
#  ization)                       ne)
#
#  conv2_block1_2_relu (Activatio  (None, 64, None, No  0          ['conv2_block1_2_bn[0][0]']
#  n)                             ne)
#
#  conv2_block1_0_conv (Conv2D)   (None, 256, None, N  16640       ['conv2_block1_preact_relu[0][0]'
#                                 one)                             ]
#
#  conv2_block1_3_conv (Conv2D)   (None, 256, None, N  16640       ['conv2_block1_2_relu[0][0]']
#                                 one)
#
#  conv2_block1_out (Add)         (None, 256, None, N  0           ['conv2_block1_0_conv[0][0]',
#                                 one)                              'conv2_block1_3_conv[0][0]']
#
#  conv2_block2_preact_bn (BatchN  (None, 256, None, N  1024       ['conv2_block1_out[0][0]']
#  ormalization)                  one)
#
#  conv2_block2_preact_relu (Acti  (None, 256, None, N  0          ['conv2_block2_preact_bn[0][0]']
#  vation)                        one)
#  conv2_block2_1_conv (Conv2D)   (None, 64, None, No  16384       ['conv2_block2_preact_relu[0][0]'
#                                 ne)                              ]
#
#  conv2_block2_1_bn (BatchNormal  (None, 64, None, No  256        ['conv2_block2_1_conv[0][0]']
#  ization)                       ne)
#
#  conv2_block2_1_relu (Activatio  (None, 64, None, No  0          ['conv2_block2_1_bn[0][0]']
#  n)                             ne)
#
#  conv2_block2_2_pad (ZeroPaddin  (None, 64, None, No  0          ['conv2_block2_1_relu[0][0]']
#  g2D)                           ne)
#
#  conv2_block2_2_conv (Conv2D)   (None, 64, None, No  36864       ['conv2_block2_2_pad[0][0]']
#                                 ne)
#
#  conv2_block2_2_bn (BatchNormal  (None, 64, None, No  256        ['conv2_block2_2_conv[0][0]']
#  ization)                       ne)
#
#  conv2_block2_2_relu (Activatio  (None, 64, None, No  0          ['conv2_block2_2_bn[0][0]']
#  n)                             ne)
#
#  conv2_block2_3_conv (Conv2D)   (None, 256, None, N  16640       ['conv2_block2_2_relu[0][0]']
#                                 one)
#
#  conv2_block2_out (Add)         (None, 256, None, N  0           ['conv2_block1_out[0][0]',
#                                 one)                              'conv2_block2_3_conv[0][0]']
#
#  conv2_block3_preact_bn (BatchN  (None, 256, None, N  1024       ['conv2_block2_out[0][0]']
#  ormalization)                  one)
#
#  conv2_block3_preact_relu (Acti  (None, 256, None, N  0          ['conv2_block3_preact_bn[0][0]']
#  vation)                        one)
#
#  conv2_block3_1_conv (Conv2D)   (None, 64, None, No  16384       ['conv2_block3_preact_relu[0][0]'
#                                 ne)                              ]
#
#  conv2_block3_1_bn (BatchNormal  (None, 64, None, No  256        ['conv2_block3_1_conv[0][0]']
#  ization)                       ne)
#
#  conv2_block3_1_relu (Activatio  (None, 64, None, No  0          ['conv2_block3_1_bn[0][0]']
#  n)                             ne)
#
#  conv2_block3_2_pad (ZeroPaddin  (None, 64, None, No  0          ['conv2_block3_1_relu[0][0]']
#  g2D)                           ne)
#
#  conv2_block3_2_conv (Conv2D)   (None, 64, None, No  36864       ['conv2_block3_2_pad[0][0]']
#                                 ne)
#
#  conv2_block3_2_bn (BatchNormal  (None, 64, None, No  256        ['conv2_block3_2_conv[0][0]']
#  ization)                       ne)
#
#  conv2_block3_2_relu (Activatio  (None, 64, None, No  0          ['conv2_block3_2_bn[0][0]']
#  n)                             ne)
#
#  max_pooling2d (MaxPooling2D)   (None, 256, None, N  0           ['conv2_block2_out[0][0]']
#                                 one)
#
#  conv2_block3_3_conv (Conv2D)   (None, 256, None, N  16640       ['conv2_block3_2_relu[0][0]']
#                                 one)
#
#  conv2_block3_out (Add)         (None, 256, None, N  0           ['max_pooling2d[0][0]',
#                                 one)                              'conv2_block3_3_conv[0][0]']
#
#  conv3_block1_preact_bn (BatchN  (None, 256, None, N  1024       ['conv2_block3_out[0][0]']
#  ormalization)                  one)
#
#  conv3_block1_preact_relu (Acti  (None, 256, None, N  0          ['conv3_block1_preact_bn[0][0]']
#  vation)                        one)
#
#  conv3_block1_1_conv (Conv2D)   (None, 128, None, N  32768       ['conv3_block1_preact_relu[0][0]'
#                                 one)                             ]
#
#  conv3_block1_1_bn (BatchNormal  (None, 128, None, N  512        ['conv3_block1_1_conv[0][0]']
#  ization)                       one)
#
#  conv3_block1_1_relu (Activatio  (None, 128, None, N  0          ['conv3_block1_1_bn[0][0]']
#  n)                             one)
#
#  conv3_block1_2_pad (ZeroPaddin  (None, 128, None, N  0          ['conv3_block1_1_relu[0][0]']
#  g2D)                           one)
#
#  conv3_block1_2_conv (Conv2D)   (None, 128, None, N  147456      ['conv3_block1_2_pad[0][0]']
#                                 one)
#
#  conv3_block1_2_bn (BatchNormal  (None, 128, None, N  512        ['conv3_block1_2_conv[0][0]']
#  ization)                       one)
#
#  conv3_block1_2_relu (Activatio  (None, 128, None, N  0          ['conv3_block1_2_bn[0][0]']
#  n)                             one)
#
#  conv3_block1_0_conv (Conv2D)   (None, 512, None, N  131584      ['conv3_block1_preact_relu[0][0]'
#                                 one)                             ]
#
#  conv3_block1_3_conv (Conv2D)   (None, 512, None, N  66048       ['conv3_block1_2_relu[0][0]']
#                                 one)
#
#  conv3_block1_out (Add)         (None, 512, None, N  0           ['conv3_block1_0_conv[0][0]',
#                                 one)                              'conv3_block1_3_conv[0][0]']
#
#  conv3_block2_preact_bn (BatchN  (None, 512, None, N  2048       ['conv3_block1_out[0][0]']
#  ormalization)                  one)
#
#  conv3_block2_preact_relu (Acti  (None, 512, None, N  0          ['conv3_block2_preact_bn[0][0]']
#  vation)                        one)
#
#  conv3_block2_1_conv (Conv2D)   (None, 128, None, N  65536       ['conv3_block2_preact_relu[0][0]'
#                                 one)                             ]
#
#  conv3_block2_1_bn (BatchNormal  (None, 128, None, N  512        ['conv3_block2_1_conv[0][0]']
#  ization)                       one)
#
#  conv3_block2_1_relu (Activatio  (None, 128, None, N  0          ['conv3_block2_1_bn[0][0]']
#  n)                             one)
#
#  conv3_block2_2_pad (ZeroPaddin  (None, 128, None, N  0          ['conv3_block2_1_relu[0][0]']
#  g2D)                           one)
#
#  conv3_block2_2_conv (Conv2D)   (None, 128, None, N  147456      ['conv3_block2_2_pad[0][0]']
#                                 one)
#
#  conv3_block2_2_bn (BatchNormal  (None, 128, None, N  512        ['conv3_block2_2_conv[0][0]']
#  ization)                       one)
#
#  conv3_block2_2_relu (Activatio  (None, 128, None, N  0          ['conv3_block2_2_bn[0][0]']
#  n)                             one)
#
#  conv3_block2_3_conv (Conv2D)   (None, 512, None, N  66048       ['conv3_block2_2_relu[0][0]']
#                                 one)
#
#  conv3_block2_out (Add)         (None, 512, None, N  0           ['conv3_block1_out[0][0]',
#                                 one)                              'conv3_block2_3_conv[0][0]']
#
#  conv3_block3_preact_bn (BatchN  (None, 512, None, N  2048       ['conv3_block2_out[0][0]']
#  ormalization)                  one)
#
#  conv3_block3_preact_relu (Acti  (None, 512, None, N  0          ['conv3_block3_preact_bn[0][0]']
#  vation)                        one)
#
#  conv3_block3_1_conv (Conv2D)   (None, 128, None, N  65536       ['conv3_block3_preact_relu[0][0]'
#                                 one)                             ]
#
#  conv3_block3_1_bn (BatchNormal  (None, 128, None, N  512        ['conv3_block3_1_conv[0][0]']
#  ization)                       one)
#
#  conv3_block3_1_relu (Activatio  (None, 128, None, N  0          ['conv3_block3_1_bn[0][0]']
#  n)                             one)
#
#  conv3_block3_2_pad (ZeroPaddin  (None, 128, None, N  0          ['conv3_block3_1_relu[0][0]']
#  g2D)                           one)
#
#  conv3_block3_2_conv (Conv2D)   (None, 128, None, N  147456      ['conv3_block3_2_pad[0][0]']
#                                 one)
#
#  conv3_block3_2_bn (BatchNormal  (None, 128, None, N  512        ['conv3_block3_2_conv[0][0]']
#  ization)                       one)
#
#  conv3_block3_2_relu (Activatio  (None, 128, None, N  0          ['conv3_block3_2_bn[0][0]']
#  n)                             one)
#
#  conv3_block3_3_conv (Conv2D)   (None, 512, None, N  66048       ['conv3_block3_2_relu[0][0]']
#                                 one)
#
#  conv3_block3_out (Add)         (None, 512, None, N  0           ['conv3_block2_out[0][0]',
#                                 one)                              'conv3_block3_3_conv[0][0]']
#
#  conv3_block4_preact_bn (BatchN  (None, 512, None, N  2048       ['conv3_block3_out[0][0]']
#  ormalization)                  one)
#
#  conv3_block4_preact_relu (Acti  (None, 512, None, N  0          ['conv3_block4_preact_bn[0][0]']
#  vation)                        one)
#
#  conv3_block4_1_conv (Conv2D)   (None, 128, None, N  65536       ['conv3_block4_preact_relu[0][0]'
#                                 one)                             ]
#
#  conv3_block4_1_bn (BatchNormal  (None, 128, None, N  512        ['conv3_block4_1_conv[0][0]']
#  ization)                       one)
#
#  conv3_block4_1_relu (Activatio  (None, 128, None, N  0          ['conv3_block4_1_bn[0][0]']
#  n)                             one)
#
#  conv3_block4_2_pad (ZeroPaddin  (None, 128, None, N  0          ['conv3_block4_1_relu[0][0]']
#  g2D)                           one)
#
#  conv3_block4_2_conv (Conv2D)   (None, 128, None, N  147456      ['conv3_block4_2_pad[0][0]']
#                                 one)
#
#  conv3_block4_2_bn (BatchNormal  (None, 128, None, N  512        ['conv3_block4_2_conv[0][0]']
#  ization)                       one)
#
#  conv3_block4_2_relu (Activatio  (None, 128, None, N  0          ['conv3_block4_2_bn[0][0]']
#  n)                             one)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 512, None, N  0          ['conv3_block3_out[0][0]']
#                                 one)
#
#  conv3_block4_3_conv (Conv2D)   (None, 512, None, N  66048       ['conv3_block4_2_relu[0][0]']
#                                 one)
#
#  conv3_block4_out (Add)         (None, 512, None, N  0           ['max_pooling2d_1[0][0]',
#                                 one)                              'conv3_block4_3_conv[0][0]']
#
#  conv4_block1_preact_bn (BatchN  (None, 512, None, N  2048       ['conv3_block4_out[0][0]']
#  ormalization)                  one)
#
#  conv4_block1_preact_relu (Acti  (None, 512, None, N  0          ['conv4_block1_preact_bn[0][0]']
#  vation)                        one)
#
#  conv4_block1_1_conv (Conv2D)   (None, 256, None, N  131072      ['conv4_block1_preact_relu[0][0]'
#                                 one)                             ]
#
#  conv4_block1_1_bn (BatchNormal  (None, 256, None, N  1024       ['conv4_block1_1_conv[0][0]']
#  ization)                       one)
#
#  conv4_block1_1_relu (Activatio  (None, 256, None, N  0          ['conv4_block1_1_bn[0][0]']
#  n)                             one)
#
#  conv4_block1_2_pad (ZeroPaddin  (None, 256, None, N  0          ['conv4_block1_1_relu[0][0]']
#  g2D)                           one)
#
#  conv4_block1_2_conv (Conv2D)   (None, 256, None, N  589824      ['conv4_block1_2_pad[0][0]']
#                                 one)
#
#  conv4_block1_2_bn (BatchNormal  (None, 256, None, N  1024       ['conv4_block1_2_conv[0][0]']
#  ization)                       one)
#
#  conv4_block1_2_relu (Activatio  (None, 256, None, N  0          ['conv4_block1_2_bn[0][0]']
#  n)                             one)
#
#  conv4_block1_0_conv (Conv2D)   (None, 1024, None,   525312      ['conv4_block1_preact_relu[0][0]'
#                                 None)                            ]
#
#  conv4_block1_3_conv (Conv2D)   (None, 1024, None,   263168      ['conv4_block1_2_relu[0][0]']
#                                 None)
#
#  conv4_block1_out (Add)         (None, 1024, None,   0           ['conv4_block1_0_conv[0][0]',
#                                 None)                             'conv4_block1_3_conv[0][0]']
#
#  conv4_block2_preact_bn (BatchN  (None, 1024, None,   4096       ['conv4_block1_out[0][0]']
#  ormalization)                  None)
#
#  conv4_block2_preact_relu (Acti  (None, 1024, None,   0          ['conv4_block2_preact_bn[0][0]']
#  vation)                        None)
#
#  conv4_block2_1_conv (Conv2D)   (None, 256, None, N  262144      ['conv4_block2_preact_relu[0][0]'
#                                 one)                             ]
#
#  conv4_block2_1_bn (BatchNormal  (None, 256, None, N  1024       ['conv4_block2_1_conv[0][0]']
#  ization)                       one)
#
#  conv4_block2_1_relu (Activatio  (None, 256, None, N  0          ['conv4_block2_1_bn[0][0]']
#  n)                             one)
#
#  conv4_block2_2_pad (ZeroPaddin  (None, 256, None, N  0          ['conv4_block2_1_relu[0][0]']
#  g2D)                           one)
#
#  conv4_block2_2_conv (Conv2D)   (None, 256, None, N  589824      ['conv4_block2_2_pad[0][0]']
#                                 one)
#
#  conv4_block2_2_bn (BatchNormal  (None, 256, None, N  1024       ['conv4_block2_2_conv[0][0]']
#  ization)                       one)
#
#  conv4_block2_2_relu (Activatio  (None, 256, None, N  0          ['conv4_block2_2_bn[0][0]']
#  n)                             one)
#
#  conv4_block2_3_conv (Conv2D)   (None, 1024, None,   263168      ['conv4_block2_2_relu[0][0]']
#                                 None)
#
#  conv4_block2_out (Add)         (None, 1024, None,   0           ['conv4_block1_out[0][0]',
#                                 None)                             'conv4_block2_3_conv[0][0]']
#
#  conv4_block3_preact_bn (BatchN  (None, 1024, None,   4096       ['conv4_block2_out[0][0]']
#  ormalization)                  None)
#
#  conv4_block3_preact_relu (Acti  (None, 1024, None,   0          ['conv4_block3_preact_bn[0][0]']
#  vation)                        None)
#
#  conv4_block3_1_conv (Conv2D)   (None, 256, None, N  262144      ['conv4_block3_preact_relu[0][0]'
#                                 one)                             ]
#
#  conv4_block3_1_bn (BatchNormal  (None, 256, None, N  1024       ['conv4_block3_1_conv[0][0]']
#  ization)                       one)
#
#  conv4_block3_1_relu (Activatio  (None, 256, None, N  0          ['conv4_block3_1_bn[0][0]']
#  n)                             one)
#
#  conv4_block3_2_pad (ZeroPaddin  (None, 256, None, N  0          ['conv4_block3_1_relu[0][0]']
#  g2D)                           one)
#
#  conv4_block3_2_conv (Conv2D)   (None, 256, None, N  589824      ['conv4_block3_2_pad[0][0]']
#                                 one)
#
#  conv4_block3_2_bn (BatchNormal  (None, 256, None, N  1024       ['conv4_block3_2_conv[0][0]']
#  ization)                       one)
#
#  conv4_block3_2_relu (Activatio  (None, 256, None, N  0          ['conv4_block3_2_bn[0][0]']
#  n)                             one)
#
#  conv4_block3_3_conv (Conv2D)   (None, 1024, None,   263168      ['conv4_block3_2_relu[0][0]']
#                                 None)
#
#  conv4_block3_out (Add)         (None, 1024, None,   0           ['conv4_block2_out[0][0]',
#                                 None)                             'conv4_block3_3_conv[0][0]']
#
#  conv4_block4_preact_bn (BatchN  (None, 1024, None,   4096       ['conv4_block3_out[0][0]']
#  ormalization)                  None)
#
#  conv4_block4_preact_relu (Acti  (None, 1024, None,   0          ['conv4_block4_preact_bn[0][0]']
#  vation)                        None)
#
#  conv4_block4_1_conv (Conv2D)   (None, 256, None, N  262144      ['conv4_block4_preact_relu[0][0]'
#                                 one)                             ]
#
#  conv4_block4_1_bn (BatchNormal  (None, 256, None, N  1024       ['conv4_block4_1_conv[0][0]']
#  ization)                       one)
#
#  conv4_block4_1_relu (Activatio  (None, 256, None, N  0          ['conv4_block4_1_bn[0][0]']
#  n)                             one)
#
#  conv4_block4_2_pad (ZeroPaddin  (None, 256, None, N  0          ['conv4_block4_1_relu[0][0]']
#  g2D)                           one)
#
#  conv4_block4_2_conv (Conv2D)   (None, 256, None, N  589824      ['conv4_block4_2_pad[0][0]']
#                                 one)
#
#  conv4_block4_2_bn (BatchNormal  (None, 256, None, N  1024       ['conv4_block4_2_conv[0][0]']
#  ization)                       one)
#
#  conv4_block4_2_relu (Activatio  (None, 256, None, N  0          ['conv4_block4_2_bn[0][0]']
#  n)                             one)
#
#  conv4_block4_3_conv (Conv2D)   (None, 1024, None,   263168      ['conv4_block4_2_relu[0][0]']
#                                 None)
#
#  conv4_block4_out (Add)         (None, 1024, None,   0           ['conv4_block3_out[0][0]',
#                                 None)                             'conv4_block4_3_conv[0][0]']
#
#  conv4_block5_preact_bn (BatchN  (None, 1024, None,   4096       ['conv4_block4_out[0][0]']
#  ormalization)                  None)
#
#  conv4_block5_preact_relu (Acti  (None, 1024, None,   0          ['conv4_block5_preact_bn[0][0]']
#  vation)                        None)
#
#  conv4_block5_1_conv (Conv2D)   (None, 256, None, N  262144      ['conv4_block5_preact_relu[0][0]'
#                                 one)                             ]
#
#  conv4_block5_1_bn (BatchNormal  (None, 256, None, N  1024       ['conv4_block5_1_conv[0][0]']
#  ization)                       one)
#
#  conv4_block5_1_relu (Activatio  (None, 256, None, N  0          ['conv4_block5_1_bn[0][0]']
#  n)                             one)
#
#  conv4_block5_2_pad (ZeroPaddin  (None, 256, None, N  0          ['conv4_block5_1_relu[0][0]']
#  g2D)                           one)
#
#  conv4_block5_2_conv (Conv2D)   (None, 256, None, N  589824      ['conv4_block5_2_pad[0][0]']
#                                 one)
#
#  conv4_block5_2_bn (BatchNormal  (None, 256, None, N  1024       ['conv4_block5_2_conv[0][0]']
#  ization)                       one)
#
#  conv4_block5_2_relu (Activatio  (None, 256, None, N  0          ['conv4_block5_2_bn[0][0]']
#  n)                             one)
#
#  conv4_block5_3_conv (Conv2D)   (None, 1024, None,   263168      ['conv4_block5_2_relu[0][0]']
#                                 None)
#
#  conv4_block5_out (Add)         (None, 1024, None,   0           ['conv4_block4_out[0][0]',
#                                 None)                             'conv4_block5_3_conv[0][0]']
#
#  conv4_block6_preact_bn (BatchN  (None, 1024, None,   4096       ['conv4_block5_out[0][0]']
#  ormalization)                  None)
#
#  conv4_block6_preact_relu (Acti  (None, 1024, None,   0          ['conv4_block6_preact_bn[0][0]']
#  vation)                        None)
#
#  conv4_block6_1_conv (Conv2D)   (None, 256, None, N  262144      ['conv4_block6_preact_relu[0][0]'
#                                 one)                             ]
#
#  conv4_block6_1_bn (BatchNormal  (None, 256, None, N  1024       ['conv4_block6_1_conv[0][0]']
#  ization)                       one)
#
#  conv4_block6_1_relu (Activatio  (None, 256, None, N  0          ['conv4_block6_1_bn[0][0]']
#  n)                             one)
#
#  conv4_block6_2_pad (ZeroPaddin  (None, 256, None, N  0          ['conv4_block6_1_relu[0][0]']
#  g2D)                           one)
#
#  conv4_block6_2_conv (Conv2D)   (None, 256, None, N  589824      ['conv4_block6_2_pad[0][0]']
#                                 one)
#
#  conv4_block6_2_bn (BatchNormal  (None, 256, None, N  1024       ['conv4_block6_2_conv[0][0]']
#  ization)                       one)
#
#  conv4_block6_2_relu (Activatio  (None, 256, None, N  0          ['conv4_block6_2_bn[0][0]']
#  n)                             one)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 1024, None,   0          ['conv4_block5_out[0][0]']
#                                 None)
#
#  conv4_block6_3_conv (Conv2D)   (None, 1024, None,   263168      ['conv4_block6_2_relu[0][0]']
#                                 None)
#
#  conv4_block6_out (Add)         (None, 1024, None,   0           ['max_pooling2d_2[0][0]',
#                                 None)                             'conv4_block6_3_conv[0][0]']
#
#  conv5_block1_preact_bn (BatchN  (None, 1024, None,   4096       ['conv4_block6_out[0][0]']
#  ormalization)                  None)
#
#  conv5_block1_preact_relu (Acti  (None, 1024, None,   0          ['conv5_block1_preact_bn[0][0]']
#  vation)                        None)
#
#  conv5_block1_1_conv (Conv2D)   (None, 512, None, N  524288      ['conv5_block1_preact_relu[0][0]'
#                                 one)                             ]
#
#  conv5_block1_1_bn (BatchNormal  (None, 512, None, N  2048       ['conv5_block1_1_conv[0][0]']
#  ization)                       one)
#
#  conv5_block1_1_relu (Activatio  (None, 512, None, N  0          ['conv5_block1_1_bn[0][0]']
#  n)                             one)
#
#  conv5_block1_2_pad (ZeroPaddin  (None, 512, None, N  0          ['conv5_block1_1_relu[0][0]']
#  g2D)                           one)
#
#  conv5_block1_2_conv (Conv2D)   (None, 512, None, N  2359296     ['conv5_block1_2_pad[0][0]']
#                                 one)
#
#  conv5_block1_2_bn (BatchNormal  (None, 512, None, N  2048       ['conv5_block1_2_conv[0][0]']
#  ization)                       one)
#
#  conv5_block1_2_relu (Activatio  (None, 512, None, N  0          ['conv5_block1_2_bn[0][0]']
#  n)                             one)
#
#  conv5_block1_0_conv (Conv2D)   (None, 2048, None,   2099200     ['conv5_block1_preact_relu[0][0]'
#                                 None)                            ]
#
#  conv5_block1_3_conv (Conv2D)   (None, 2048, None,   1050624     ['conv5_block1_2_relu[0][0]']
#                                 None)
#
#  conv5_block1_out (Add)         (None, 2048, None,   0           ['conv5_block1_0_conv[0][0]',
#                                 None)                             'conv5_block1_3_conv[0][0]']
#
#  conv5_block2_preact_bn (BatchN  (None, 2048, None,   8192       ['conv5_block1_out[0][0]']
#  ormalization)                  None)
#
#  conv5_block2_preact_relu (Acti  (None, 2048, None,   0          ['conv5_block2_preact_bn[0][0]']
#  vation)                        None)
#
#  conv5_block2_1_conv (Conv2D)   (None, 512, None, N  1048576     ['conv5_block2_preact_relu[0][0]'
#                                 one)                             ]
#
#  conv5_block2_1_bn (BatchNormal  (None, 512, None, N  2048       ['conv5_block2_1_conv[0][0]']
#  ization)                       one)
#
#  conv5_block2_1_relu (Activatio  (None, 512, None, N  0          ['conv5_block2_1_bn[0][0]']
#  n)                             one)
#
#  conv5_block2_2_pad (ZeroPaddin  (None, 512, None, N  0          ['conv5_block2_1_relu[0][0]']
#  g2D)                           one)
#
#  conv5_block2_2_conv (Conv2D)   (None, 512, None, N  2359296     ['conv5_block2_2_pad[0][0]']
#                                 one)
#
#  conv5_block2_2_bn (BatchNormal  (None, 512, None, N  2048       ['conv5_block2_2_conv[0][0]']
#  ization)                       one)
#
#  conv5_block2_2_relu (Activatio  (None, 512, None, N  0          ['conv5_block2_2_bn[0][0]']
#  n)                             one)
#
#  conv5_block2_3_conv (Conv2D)   (None, 2048, None,   1050624     ['conv5_block2_2_relu[0][0]']
#                                 None)
#
#  conv5_block2_out (Add)         (None, 2048, None,   0           ['conv5_block1_out[0][0]',
#                                 None)                             'conv5_block2_3_conv[0][0]']
#
#  conv5_block3_preact_bn (BatchN  (None, 2048, None,   8192       ['conv5_block2_out[0][0]']
#  ormalization)                  None)
#
#  conv5_block3_preact_relu (Acti  (None, 2048, None,   0          ['conv5_block3_preact_bn[0][0]']
#  vation)                        None)
#
#  conv5_block3_1_conv (Conv2D)   (None, 512, None, N  1048576     ['conv5_block3_preact_relu[0][0]'
#                                 one)                             ]
#
#  conv5_block3_1_bn (BatchNormal  (None, 512, None, N  2048       ['conv5_block3_1_conv[0][0]']
#  ization)                       one)
#
#  conv5_block3_1_relu (Activatio  (None, 512, None, N  0          ['conv5_block3_1_bn[0][0]']
#  n)                             one)
#
#  conv5_block3_2_pad (ZeroPaddin  (None, 512, None, N  0          ['conv5_block3_1_relu[0][0]']
#  g2D)                           one)
#
#  conv5_block3_2_conv (Conv2D)   (None, 512, None, N  2359296     ['conv5_block3_2_pad[0][0]']
#                                 one)
#
#  conv5_block3_2_bn (BatchNormal  (None, 512, None, N  2048       ['conv5_block3_2_conv[0][0]']
#  ization)                       one)
#
#  conv5_block3_2_relu (Activatio  (None, 512, None, N  0          ['conv5_block3_2_bn[0][0]']
#  n)                             one)
#
#  conv5_block3_3_conv (Conv2D)   (None, 2048, None,   1050624     ['conv5_block3_2_relu[0][0]']
#                                 None)
#
#  conv5_block3_out (Add)         (None, 2048, None,   0           ['conv5_block2_out[0][0]',
#                                 None)                             'conv5_block3_3_conv[0][0]']
#
#  post_bn (BatchNormalization)   (None, 2048, None,   8192        ['conv5_block3_out[0][0]']
#                                 None)
#
#  post_relu (Activation)         (None, 2048, None,   0           ['post_bn[0][0]']
#                                 None)
#
# ==================================================================================================
# Total params: 23,564,800
# Trainable params: 0
# Non-trainable params: 23,564,800
# __________________________________________________________________________________________________

# %% [markdown]
# ### Load data and set model parameters

# %%
nclasses = 33 #Number of classes in training data

# %%
import glob

from rioxarray.exceptions import NoDataInBounds

# %%
rgb_paths = glob.glob('./train/RemoteSensing/RGB/*.tif')
bboxes_paths = glob.glob('./train/ITC/train_*.shp')
classes_path = './train/Field/train_data.csv'

# Load training and test data and corresponding labels
class IDTreeSDataset:
    
    def __init__(self, rgb_paths, bboxes_paths, classes_path):
        self.rgb_paths = rgb_paths
        self.bboxes_paths = bboxes_paths
        self.classes_path = classes_path
        
    def generate_cutouts(self):
        # load bboxes
        bboxes = pd.concat([
            geopandas.read_file(p)
            for p in self.bboxes_paths
        ])
        
        # load classes 
        classes = pd.read_csv(self.classes_path)
        classes = classes.set_index('indvdID')

        # load rgb data and make cutouts
        for rgb_path in self.rgb_paths:
            rgb = rioxarray.open_rasterio(rgb_path, masked=True)
            
            assert bboxes.crs == rgb.rio.crs

            # select relevant bboxes
            xmin, ymin, xmax, ymax = rgb.rio.bounds()
            bboxes_clip = bboxes.cx[xmin:xmax, ymin:ymax]
            bboxes_clip = bboxes_clip[~bboxes_clip.is_empty]
            
            for _, bbox in bboxes_clip.iterrows():
                
                indvdID = bbox['indvdID']

                if indvdID not in classes.index:
                    # issue: for some IDs, the class is not specified
                    continue
                
                label = classes.loc[indvdID]['taxonID']
                if not isinstance(label, str):
                    # issue: there are multiple entries for the same ID
                    continue
                
                try:
                    cutout = rgb.rio.clip([bbox.geometry], drop=True)
                    data, flag = _image_preprocessor(cutout.data)
                    if flag:
                        # If image is too small or too large
                        continue
                except NoDataInBounds:
                    # issue: some polygons have very small intersections with the images
                    continue
                yield indvdID, label, data
    
def _image_preprocessor(data):
    if (_remove_large_image(data) or _remove_small_images(data)):
        return data, True
    data = _image_padding(data)
    return data, False

def _remove_large_image(data):
    if max(data.shape[1:]) > 100:
        return True

def _remove_small_images(data):
    if min(data.shape[1:]) <= 32:
        return True

def _image_padding(data):
    #Pad each image 
    pad_width_x1 = np.floor((100 - data.shape[1])/2).astype(int)
    pad_width_x2 = 100 - data.shape[1] - pad_width_x1 
    pad_width_y1 = np.floor((100 - data.shape[2])/2).astype(int)
    pad_width_y2 = 100 - data.shape[2] - pad_width_y1
    data = np.pad(data, pad_width=[(0, 0),(pad_width_x1, pad_width_x2),(pad_width_y1, pad_width_y2)], mode='constant')
    return data
        

ds = IDTreeSDataset(rgb_paths, bboxes_paths, classes_path)

ds = tf.data.Dataset.from_generator(
    ds.generate_cutouts,
    output_signature=(
        tf.TensorSpec(shape=(), dtype=tf.string),
        tf.TensorSpec(shape=(), dtype=tf.string),
        tf.TensorSpec(shape=(3, None, None), dtype=tf.float32)
    )
)

# %% [markdown]
# ### Create new model using the base model plus additional layers

# %%
def create_model():
    # Inputs
    inputs = keras.Input(shape=(3, 100, 100))

    # Run input image through our base model (ResNet)
    x = base_model(inputs, training = False)

    # Convert features from base model to a vector
    x = keras.layers.GlobalAveragePooling2D()(x)

    # Create additional dense layers to fine tune the model
    x = keras.layers.Dense(256)(x)
    x = keras.layers.Dense(64)(x)

    # Create output layer
    outputs = keras.layers.Dense(nclasses)(x)

    return keras.Model(inputs, outputs)

model = create_model()

# %%
# Compile the model
model.compile(optimizer=keras.optimizers.Adam(), 
              loss=keras.losses.CategoricalCrossentropy(from_logits=True))

# %%
# Train the model
model.fit(dataset, epochs=..., validation_data=...)

# %%
# Predict on the test set
model.predict()
